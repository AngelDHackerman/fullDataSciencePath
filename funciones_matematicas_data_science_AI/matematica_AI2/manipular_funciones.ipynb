# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Desplazamientos verticales y horizontales
# Siendo  c  una constante mayor que cero, entonces la gráfica:
#
# y=f(x)+c  se desplaza  c  unidades hacia arriba.
#
# y=f(x)−c  se desplaza  c  unidades hacia abajo.
#
# y=f(x−c)  se desplaza  c  unidades hacia la derecha.
#
# y=f(x+c)  se desplaza  c  unidades hacia la izquierda.

# %%
N = 1000

def f(x):
  return x**2

c = 0

x = np.linspace(-5, 5, num=N)

y = f(x)

fig, ax = plt.subplots()
ax.plot(x, y)  # Esto crea la linea en el canvas "fig"
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Desplazando 5 unidades hacia arriba:

# %%
N = 1000

def f(x):
  return x**2

c = 5

x = np.linspace(-5, 5, num=N)

y = f(x) + c

fig, ax = plt.subplots()
ax.plot(x, y)  # Esto crea la linea en el canvas "fig"
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Desplanzando 5 unidades hacia abajo:

# %%
N = 1000

def f(x):
  return x**2

c = 5

x = np.linspace(-5, 5, num=N)

y = f(x) - c

fig, ax = plt.subplots()
ax.plot(x, y)  # Esto crea la linea en el canvas "fig"
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Desplazando hacia la derecha:

# %%
N = 1000

def f(x):
  return x**2

c = 3

x = np.linspace(-25, 25, num=N)

y = f(x - c)

fig, ax = plt.subplots()
ax.plot(x, y)  # Esto crea la linea en el canvas "fig"
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Desplazando hacia la izquierda:

# %%
N = 1000

def f(x):
  return x**2

c = 3

x = np.linspace(-25, 25, num=N)

y = f(x + c)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Alargamientos y compresiones
#
# Siendo  c  una constante mayor que cero, entonces la gráfica:
#
# y=c⋅f(x)  alarga la gráfica verticalmente en un factor de  c .
#
# y=1c⋅f(x)  comprime la gráfica verticalmente en un factor de  c .
#
# y=f(c⋅x)  comprime la gráfica horizontelmente en un factor de  c .
#
# y=f(1c⋅x)  alarga la gráfica horizontelmente en un factor de  c .

# %%
N = 1000

def f(x):
  return np.sin(x)

c = 2

x = np.linspace(-15, 15, num=N)

y = f(x)

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Alargado vertical de la grafica:

# %%
N = 1000

def f(x):
  return np.sin(x)

c = 2

x = np.linspace(-15, 15, num=N)

y = c * f(x)  # aqui se hace la modificacion de la grafica

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Compresion en horizontal:

# %%
N = 1000

def f(x):
  return np.sin(x)

c = 2

x = np.linspace(-15, 15, num=N)

y = (1/c) * f(x)  # aqui se hace la modificacion de la grafica

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Compresion horizontal de la grafica:

# %%
N = 1000

def f(x):
  return np.sin(x)

c = 2

x = np.linspace(-15, 15, num=N)

y = f(c * x)  # aqui se hace la modificacion de la grafica

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ### Alargamiento de la grafica en horizontal:

# %%
N = 1000

def f(x):
  return np.sin(x)

c = 2

x = np.linspace(-15, 15, num=N)

y = f((1/c) * x)  # aqui se hace la modificacion de la grafica

fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
ax.axhline(y = 0, color='r')
ax.axvline(x = 0, color='g')

# %% [markdown]
# ## Reflexiones
#
# y=−f(x)  refleja la gráfica respecto al eje x.
#
# y=f(−x)  refleja la gráfica respecto al eje y.

# %%
N = 1000

def f(x):
  return x**3;

x = np.linspace(-10,10, num=N)

y = f(x)

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='g')

# %% [markdown]
# ### Reflejando respecto al eje X:

# %%
N = 1000

def f(x):
  return x**3;

x = np.linspace(-10,10, num=N)

y = -f(x)  # Aqui se hace el cambio a la grafica

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='g')

# %% [markdown]
# ### Reflejando respecto al eje de Y

# %%
N = 1000

def f(x):
  return x**3;

x = np.linspace(-10,10, num=N)

y = f(-x)  # Aqui se hace el cambio a la grafica

fig, ax = plt.subplots()
ax.plot(x,y)
ax.grid()
ax.axhline(y=0, color='r')
ax.axvline(x=0, color='g')
